# %% [markdown]
# # FGSM Fashion MNIST Dataset Development

# %% [markdown]
# <div style="text-align: justify">
# The fast gradient sign method works by using the gradients of the neural network to create an adversarial example. For an input image, the method uses the gradients of the loss with respect to the input image to create a new image that maximises the loss. This new image is called the adversarial image. This can be summarised using the following expression:
# </div>
#
# <div style="margin-top:20px">
# $adv_x = x + \epsilon \times sign(\nabla_xJ(\theta, x, y))$, where:
# </div>
#
# - $adv_x$ : Adversarial image.
# - $x$ : Original input image.
# - $y$ : Original input label.
# - $\epsilon$ : Multiplier to ensure the perturbations are small.
# - $\theta$ : Model parameters.
# - $J$ : Loss.
#
# <div style="text-align: justify">
# An intriguing property here, is the fact that the gradients are taken with respect to the input image. This is done because the objective is to create an image that maximises the loss. A method to accomplish this is to find how much each pixel in the image contributes to the loss value, and add a perturbation accordingly. This works pretty fast because it is easy to find how each input pixel contributes to the loss by using the chain rule and finding the required gradients. Hence, the gradients are taken with respect to the image. In addition, since the model is no longer being trained (thus the gradient is not taken with respect to the trainable variables, i.e., the model parameters), and so the model parameters remain constant. <mark>The only goal is to fool an already trained model.</mark>
# </div>

# %%
# Tensorflow logging: OFF
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# TensorFlow
import tensorflow as tf

# CNN layers
from tensorflow.keras import layers, models

# Optimiziers
from tensorflow.keras.optimizers import Adam

# Others
from tensorflow.keras import Input

# Helper libraries
import numpy as np
import matplotlib.pyplot as mpl

print(tf.__version__)
# Out:
# 2.15.0

# %%
# Plot configurations for later observations
mpl.rcParams['figure.figsize'] = (5, 5)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ### Loading Fashion MNIST dataset

# %%
# Load Fashion MNIST
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
#
# - The `train_images` and `train_labels` arrays are the training set—the data the model uses to learn.
# - The model is tested against the test set, the `test_images`, and `test_labels` arrays.
#
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255. The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# | <div style="width:300px">**Label**</div> |  <div style="width:450px">**Class**</div>  |
# |:----------|:------------|
# | 0         | T-shirt/top |
# | 1         | Trouser     |
# | 2         | Pullover    |
# | 3         | Dress       |
# | 4         | Coat        |
# | 5         | Sandal      |
# | 6         | Shirt       |
# | 7         | Sneaker     |
# | 8         | Bag         |
# | 9         | Ankle boot  |
#
# Each image is mapped to a single label. Since the class names are not included with the dataset, store them here to use later when plotting the images:

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
num_classes = len(class_names)

# %% [markdown]
# ### Explore the data

# %%
print(f"Train Set Shape: {train_images.shape}")
# Out:
# Train Set Shape: (60000, 28, 28)

# %%
print(f"Test Set Shape: {test_images.shape}")
# Out:
# Test Set Shape: (10000, 28, 28)

# %%
print(f"Train Labels Length: {len(train_labels)}")
# Out:
# Train Labels Length: 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
print(f"Test Labels Length: {len(test_labels)}")
# Out:
# Test Labels Length: 10000

# %% [markdown]
# ### Preprocess the data

# %% [markdown]
# The data must be preprocessed before training the network. If we inspect the first image in the training set, we will see that the pixel values fall in the range of 0 to 255:

# %%
mpl.figure()
mpl.imshow(train_images[0])
mpl.colorbar()
mpl.grid(False)
mpl.show()

# %% [markdown]
# We will scale these values to a range of 0 to 1 before feeding them to the neural network model. To do so, we must divide the values by 255. It's important that the training set and the testing set be preprocessed in the same way:

# %%
# Normalize the data
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Reshape the images to add the mono channel dimension (1)
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1)
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)

# %%
mpl.figure(figsize=(7,7))
for i in range(25):
    mpl.subplot(5,5,i+1)
    mpl.xticks([])
    mpl.yticks([])
    mpl.grid(False)
    mpl.imshow(train_images[i], cmap=mpl.cm.binary)
    mpl.xlabel(class_names[train_labels[i]])
mpl.show()

# %% [markdown]
# ### Model creation + training

# %%
# Define the CNN model
model = models.Sequential()

# Convolutional and pooling layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten layer to transition from convolutional to dense layers
model.add(layers.Flatten())

# Dense layers
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10))

# %%
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=10000, decay_rate=0.9, staircase=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_images,
    train_labels,
    epochs=10,
    validation_data=(test_images, test_labels)
)

# %%
# Plot training & validation accuracy values
mpl.figure(figsize=(6,4))
mpl.plot(history.history['accuracy'])
mpl.plot(history.history['val_accuracy'])
mpl.title('Model accuracy')
mpl.ylabel('Accuracy')
mpl.xlabel('Epochs')
mpl.legend(['Train', 'Test'], loc='upper left')
mpl.show()

# %% [markdown]
# ### Save the model

# %%
MODEL_TRAINED = "./Models/FashionMNIST-Normal.keras"
model.save(MODEL_TRAINED)

# %% [markdown]
# ### Load pretrained model

# %%
MODEL_TRAINED = "./Models/FashionMNIST-Normal.keras"
model = tf.keras.models.load_model(MODEL_TRAINED)

# %% [markdown]
# ### Test accuracy and predictions

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 2s - loss: 0.3052 - accuracy: 0.9138 - 2s/epoch - 5ms/step
#
# Test accuracy: 0.9138000011444092

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i], img[i]
    mpl.grid(False)
    mpl.xticks([])
    mpl.yticks([])
    
    mpl.imshow(img, cmap=mpl.cm.binary)
    predicted_label = np.argmax(predictions_array)
    
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    
    mpl.xlabel("{} {:2.0f}% ({})".format(
        class_names[predicted_label],
        100*np.max(predictions_array),
        class_names[true_label]),
        color=color
    )

def plot_value_array(i, predictions_array, true_label):
    true_label = true_label[i]
    mpl.grid(False)
    mpl.xticks(range(10))
    mpl.yticks([])
    
    thisplot = mpl.bar(range(10), predictions_array, color="#777777")
    mpl.ylim([0, 1])
    
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 0
mpl.figure(figsize=(6,3))
mpl.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
mpl.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
mpl.show()

# %%
i = 12
mpl.figure(figsize=(6,3))
mpl.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
mpl.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
mpl.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
mpl.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    mpl.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions[i], test_labels, test_images)
    mpl.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], test_labels)
mpl.tight_layout()
mpl.savefig('Figures/Predictions-Normal/PredictionsFashionMNIST.png', bbox_inches='tight')
mpl.show()

# %% [markdown]
# ### Creating the adversarial image pattern

# %% [markdown]
# The first step is to create perturbations which will be used to distort the original image resulting in an adversarial image. As mentioned, for this task, the gradients are taken with respect to the image.

# %%
loss_object = tf.keras.losses.CategoricalCrossentropy()

def create_adversarial_pattern(input_image, input_label, noise_factor=0.2):
    with tf.GradientTape() as tape:
        tape.watch(input_image)
        prediction = model(input_image)
        loss = loss_object(input_label, prediction)

    # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)
    
    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    signed_grad = tf.image.resize(signed_grad, (28, 28))

    # Add more noise to the adversarial pattern
    noisy_signed_grad = signed_grad + noise_factor * tf.random.normal(tf.shape(signed_grad))

    return noisy_signed_grad

# %%
def fgsm_attack(image_index):
    # Choose image and label with the model prediction
    image = (np.expand_dims(train_images[image_index], 0))
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    image_probs = probability_model.predict(image, verbose=0)
    
    label = train_labels[image_index]
    label = tf.one_hot(image_index, image_probs.shape[-1])
    label = tf.reshape(label, (1, image_probs.shape[-1]))

    # Create the perturbation pattern
    perturbations = create_adversarial_pattern(image, label)
    # mpl.imshow(perturbations[0] * 0.5 + 0.5) # Uncommnet for debug purposes, i.e, visualise the perturbation

    return (image, perturbations)

# %%
def get_stats(image):
    image = (np.expand_dims(image, 0))
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    image_probs = probability_model.predict(image, verbose=0)
    label = class_names[np.argmax(image_probs)]
    confidence = 100*np.max(image_probs)
    return (label, confidence, np.argmax(image_probs))

# %%
def display_images(image, description, label, confidence, image_index, adv_label_num):
    mpl.figure()
    mpl.imshow(image[0]*0.5+0.5, cmap='gray')
    mpl.title('{} \n {} : {:.2f}% Confidence'.format(description, label, confidence))
    mpl.savefig(f"Figures/FGSMDataset-Epsilon0160-PNGs/{image_index:05}_{adv_label_num}.png", bbox_inches='tight')
    # mpl.show() # Uncommnet for debug purposes, i.e, visualise the different levels of perturbations
    mpl.close()

# %% [markdown]
# ### Using the pattern to create an adversarial image

# %%
epsilons = [0, 0.01, 0.1, 0.15, 0.2]
descriptions = [('Epsilon = {:0.3f}'.format(eps) if eps else 'Input') for eps in epsilons]

id = 0
image_index = 3
image, perturbations = fgsm_attack(image_index)

for i, eps in enumerate(epsilons):
    adv_x = image + eps*perturbations
    adv_x = tf.clip_by_value(adv_x, -1, 1)
    id+=1
    label, confidence, _ = get_stats(adv_x[0])
    display_images(adv_x, descriptions[i], label, confidence, image_index, _)

# %% [markdown]
# ### Using the adversarial pattern to create the dataset

# %% [markdown]
# Following multiple tests and result analyses, the decision was made to generate the dataset with the corresponding $\epsilon$ set to 0.1.

# %%
epsilon = 0.16
# epsilon = 0.1

description = 'Epsilon = {:0.3f}'.format(epsilon)

adversarial_images = []
misclassified_labels = []

# for i in range(len(train_images)):
for i in range(10000):
    image_index = i
    image, perturbations = fgsm_attack(image_index)

    # Creation of the adversarial image
    adv_x = image+epsilon*perturbations
    adv_x = tf.clip_by_value(adv_x, -1, 1)
    
    id = len(adversarial_images) + 1
    label_name, confidence, label_num = get_stats(adv_x[0])
    
    # Check if the label is misclassified
    original_label_name, _, original_label_num = get_stats(image[0])
    
    print(f"[INFO] FGSM Perturbation ({epsilon:0.3f}): Figure {image_index:05} - Original Label ({original_label_num}:{original_label_name}); FGSM Label ({label_num}:{label_name})")

    if label_num != original_label_num:
        adversarial_label_num = 10*1+original_label_num
    
        adversarial_images.append(adv_x)
        misclassified_labels.append(adversarial_label_num)
        
        display_images(adv_x, description, label_name, confidence, image_index, adversarial_label_num)

# Convert the lists to numpy arrays
adversarial_images = np.array(adversarial_images)
misclassified_labels = np.array(misclassified_labels)

# Save the dataset to a .npz file
# np.savez('FGSMDataset/Dataset.npz', adversarial_images=adversarial_images, misclassified_labels=misclassified_labels)
# Out:
# [INFO] FGSM Perturbation (0.160): Figure 00000 - Original Label (9:Ankle boot); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00001 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00002 - Original Label (0:T-shirt/top); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00003 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00004 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00005 - Original Label (2:Pullover); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00006 - Original Label (7:Sneaker); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00007 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00008 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00009 - Original Label (5:Sandal); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00010 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00011 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00012 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00013 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00014 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00015 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00016 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00017 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00018 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00019 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00020 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00021 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00022 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00023 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00024 - Original Label (2:Pullover); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00025 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00026 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00027 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00028 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00029 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00030 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00031 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00032 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00033 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00034 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00035 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00036 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00037 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00038 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00039 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00040 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00041 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00042 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00043 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00044 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00045 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00046 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00047 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00048 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00049 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00050 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00051 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00052 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00053 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00054 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00055 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00056 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00057 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00058 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00059 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00060 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00061 - Original Label (0:T-shirt/top); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00062 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00063 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00064 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00065 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00066 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00067 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00068 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00069 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00070 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00071 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00072 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00073 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00074 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00075 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00076 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00077 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00078 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00079 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00080 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00081 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00082 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00083 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00084 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00085 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00086 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00087 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00088 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00089 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00090 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00091 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00092 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00093 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00094 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00095 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00096 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00097 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00098 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00099 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00100 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00101 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00102 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00103 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00104 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00105 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00106 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00107 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00108 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00109 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00110 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00111 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00112 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00113 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00114 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00115 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00116 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00117 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00118 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00119 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00120 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00121 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00122 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00123 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00124 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00125 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00126 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00127 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00128 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00129 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00130 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00131 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00132 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00133 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00134 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00135 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00136 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00137 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00138 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00139 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00140 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00141 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00142 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00143 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00144 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00145 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00146 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00147 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00148 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00149 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00150 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00151 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00152 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00153 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00154 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00155 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00156 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00157 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00158 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00159 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00160 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00161 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00162 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00163 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00164 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00165 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00166 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00167 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00168 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00169 - Original Label (0:T-shirt/top); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00170 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00171 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00172 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00173 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00174 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00175 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00176 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00177 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00178 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00179 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00180 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00181 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00182 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00183 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00184 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00185 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00186 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00187 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00188 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00189 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00190 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00191 - Original Label (0:T-shirt/top); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00192 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00193 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00194 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00195 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00196 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00197 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00198 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00199 - Original Label (2:Pullover); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00200 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00201 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00202 - Original Label (0:T-shirt/top); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00203 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00204 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00205 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00206 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00207 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00208 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00209 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00210 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00211 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00212 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00213 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00214 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00215 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00216 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00217 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00218 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00219 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00220 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00221 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00222 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00223 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00224 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00225 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00226 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00227 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00228 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00229 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00230 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00231 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00232 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00233 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00234 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00235 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00236 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00237 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00238 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00239 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00240 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00241 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00242 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00243 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00244 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00245 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00246 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00247 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00248 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00249 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00250 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00251 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00252 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00253 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00254 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00255 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00256 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00257 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00258 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00259 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00260 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00261 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00262 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00263 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00264 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00265 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00266 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00267 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00268 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00269 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00270 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00271 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00272 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00273 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00274 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00275 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00276 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00277 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00278 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00279 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00280 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00281 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00282 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00283 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00284 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00285 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00286 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00287 - Original Label (8:Bag); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00288 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00289 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00290 - Original Label (2:Pullover); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00291 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00292 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00293 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00294 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00295 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00296 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00297 - Original Label (6:Shirt); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00298 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00299 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00300 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00301 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00302 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00303 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00304 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00305 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00306 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00307 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00308 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00309 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00310 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00311 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00312 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00313 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00314 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00315 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00316 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00317 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00318 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00319 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00320 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00321 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00322 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00323 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00324 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00325 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00326 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00327 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00328 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00329 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00330 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00331 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00332 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00333 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00334 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00335 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00336 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00337 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00338 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00339 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00340 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00341 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00342 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00343 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00344 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00345 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00346 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00347 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00348 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00349 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00350 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00351 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00352 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00353 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00354 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00355 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00356 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00357 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00358 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00359 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00360 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00361 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00362 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00363 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00364 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00365 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00366 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00367 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00368 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00369 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00370 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00371 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00372 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00373 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00374 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00375 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00376 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00377 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00378 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00379 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00380 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00381 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00382 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00383 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00384 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00385 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00386 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00387 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00388 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00389 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00390 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00391 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00392 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00393 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00394 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00395 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00396 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00397 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00398 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00399 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00400 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00401 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00402 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00403 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00404 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00405 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00406 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00407 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00408 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00409 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00410 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00411 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00412 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00413 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00414 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00415 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00416 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00417 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00418 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00419 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00420 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00421 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00422 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00423 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00424 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00425 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00426 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00427 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00428 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00429 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00430 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00431 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00432 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00433 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00434 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00435 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00436 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00437 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00438 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00439 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00440 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00441 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00442 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00443 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00444 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00445 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00446 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00447 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00448 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 00449 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00450 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00451 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00452 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00453 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00454 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00455 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00456 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00457 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00458 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00459 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00460 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 00461 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00462 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 00463 - Original Label (4:Coat); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00464 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00465 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00466 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00467 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00468 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00469 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00470 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 00471 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00472 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00473 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00474 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00475 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 00476 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 00477 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00478 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 00479 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 00480 - Original Label (6:Shirt); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00481 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 00482 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 00483 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# ...
# [INFO] FGSM Perturbation (0.160): Figure 09839 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09840 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09841 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09842 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09843 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09844 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09845 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09846 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09847 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09848 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09849 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09850 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09851 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09852 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09853 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09854 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09855 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09856 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09857 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09858 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09859 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09860 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09861 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09862 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09863 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09864 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09865 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09866 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09867 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09868 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09869 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09870 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09871 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09872 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09873 - Original Label (0:T-shirt/top); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09874 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09875 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09876 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09877 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09878 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09879 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09880 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09881 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09882 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09883 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09884 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09885 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09886 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09887 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09888 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09889 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09890 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09891 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09892 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09893 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09894 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09895 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09896 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09897 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09898 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09899 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09900 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09901 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09902 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09903 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09904 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09905 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09906 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09907 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09908 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09909 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09910 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09911 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09912 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09913 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09914 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09915 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09916 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09917 - Original Label (0:T-shirt/top); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09918 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09919 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09920 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09921 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09922 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09923 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09924 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09925 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09926 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09927 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09928 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09929 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09930 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09931 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09932 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09933 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09934 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09935 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09936 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09937 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09938 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09939 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09940 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09941 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09942 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09943 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09944 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09945 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09946 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09947 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09948 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09949 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09950 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09951 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09952 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09953 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09954 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09955 - Original Label (2:Pullover); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09956 - Original Label (6:Shirt); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09957 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09958 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09959 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09960 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09961 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09962 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09963 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09964 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09965 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09966 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09967 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09968 - Original Label (2:Pullover); FGSM Label (2:Pullover)
# [INFO] FGSM Perturbation (0.160): Figure 09969 - Original Label (0:T-shirt/top); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09970 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09971 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09972 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09973 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09974 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09975 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09976 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09977 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09978 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09979 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09980 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09981 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09982 - Original Label (8:Bag); FGSM Label (8:Bag)
# [INFO] FGSM Perturbation (0.160): Figure 09983 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09984 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09985 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09986 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09987 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09988 - Original Label (1:Trouser); FGSM Label (1:Trouser)
# [INFO] FGSM Perturbation (0.160): Figure 09989 - Original Label (3:Dress); FGSM Label (3:Dress)
# [INFO] FGSM Perturbation (0.160): Figure 09990 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09991 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09992 - Original Label (9:Ankle boot); FGSM Label (9:Ankle boot)
# [INFO] FGSM Perturbation (0.160): Figure 09993 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09994 - Original Label (4:Coat); FGSM Label (4:Coat)
# [INFO] FGSM Perturbation (0.160): Figure 09995 - Original Label (7:Sneaker); FGSM Label (7:Sneaker)
# [INFO] FGSM Perturbation (0.160): Figure 09996 - Original Label (5:Sandal); FGSM Label (5:Sandal)
# [INFO] FGSM Perturbation (0.160): Figure 09997 - Original Label (0:T-shirt/top); FGSM Label (0:T-shirt/top)
# [INFO] FGSM Perturbation (0.160): Figure 09998 - Original Label (6:Shirt); FGSM Label (6:Shirt)
# [INFO] FGSM Perturbation (0.160): Figure 09999 - Original Label (6:Shirt); FGSM Label (6:Shirt)
